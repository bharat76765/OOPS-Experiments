# %% [markdown]
# <a href="https://colab.research.google.com/github/bharat76765/OOPS-Experiments/blob/main/OOP%20project1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
class project1:
  def __init__(self,name):
    self.name=name
    self.database={}
    self.menu1()
  def menu1(self):
    print("""
    hey {} choose what you wish to do
    1.Register
    2.Login
    3.aise hei chala aya""".format(self.name))
    choice1=int(input("enter your choice"))
    print()
    print("..............................................................................................")
    print()
    if choice1==1:
      self.Register()
    elif choice1==2:
      self.Login()
    else:
      print("aise kaise")
      exit()
  def Register(self):
    email=input("enter your email")
    password=input("enter your password")
    if email in self.database:
      print("email already exists")
      self.menu1()
    else:
      self.database[email]=[self.name,password]
      print("registered successfully")
      self.menu1()
  def Login(self):
    email=input("enter your email")
    password=input("enter your password")
    if email in self.database:
      print("login successful")
      self.menu2()
    else:
      print("email not found,please register")
      self.menu1()
  def menu2(self):
    print()
    print("..............................................................................................")
    print()
    print("hey {}".format(self.name))
    print('''
    what you wish to do now
    1. check wheather
    2. go back to previous menu
    3. Exit''')
    choice2=int(input("enter your choice"))
    if choice2==1:
      self.wheather()
    elif choice2==2:
      self.menu1()
    else:
      print("aise kaise")
      exit()
  def wheather(self):
    print("hey , {} write the latitude , longitude".format(self.name))
    lat=float(input("enter latitude"))
    lon=float(input("enter longitude"))
    print()
    print("..............................................................................................")
    print()
    url = "https://weatherbit-v1-mashape.p.rapidapi.com/forecast/3hourly"
    querystring = {"lat":str(lat),"lon":str(lon),"units":"imperial","lang":"en"}
    headers = {
      "x-rapidapi-key": "0d839b48d3mshdb2c1ee05b2a2b8p1fafedjsn8404b2c208db",
      "x-rapidapi-host": "weatherbit-v1-mashape.p.rapidapi.com"
    }
    response = requests.get(url, headers=headers, params=querystring)
    d=dict(response.json())
    for i in d:
      print (i,d[i])
    print()
    print("..............................................................................................")
    print()
    self.menu2()

# %%
b=project1("Bharat")
# Out:
#     hey Bharat choose what you wish to do
#     1.Register
#     2.Login
#     3.aise hei chala aya
# enter your choice1
#
# ..............................................................................................
#
# enter your emailbharat@gmail.com
# enter your password1234
# registered successfully
#
#     hey Bharat choose what you wish to do
#     1.Register
#     2.Login
#     3.aise hei chala aya
# enter your choice2
#
# ..............................................................................................
#
# enter your emailbharat@123
# enter your password1234
# email not found,please register
#
#     hey Bharat choose what you wish to do
#     1.Register
#     2.Login
#     3.aise hei chala aya
# enter your choice2
#
# ..............................................................................................
#
# enter your emailbharat@gmail.com
# enter your password1234
# login successful
#
# ..............................................................................................
#
# hey Bharat
#
#     what you wish to do now
#     1. check wheather
#     2. go back to previous menu
#     3. Exit
# enter your choice1
# hey , Bharat write the latitude , longitude
# enter latitude14.611
# enter longitude75.638
#
# ..............................................................................................
#
# data [{'wind_cdir': 'SW', 'rh': 89, 'pod': 'n', 'pres': 945.5, 'snow': 0, 'vis': 14.9, 'solar_rad': 0, 'wind_spd': 4.4, 'wind_cdir_full': 'southwest', 'slp': 1007.5, 'datetime': '2024-06-15:21', 'ts': 1718485200, 'wind_gust_spd': 9.6, 'dewpt': 71.2, 'uv': 0, 'ozone': 273.3, 'clouds_hi': 10, 'clouds_low': 69, 'clouds_mid': 43, 'timestamp_utc': '2024-06-15T21:00:00', 'wind_dir': 236, 'timestamp_local': '2024-06-16T02:30:00', 'pop': 0, 'snow_depth': 0, 'precip': 0, 'weather': {'icon': 'c02n', 'description': 'Scattered clouds', 'code': 802}, 'dni': 0, 'app_temp': 76, 'temp': 74.7, 'clouds': 57, 'dhi': 0, 'ghi': 0}, {'wind_cdir': 'WSW', 'rh': 90, 'pod': 'n', 'pres': 945.5, 'snow': 0, 'vis': 14.9, 'solar_rad': 0, 'wind_spd': 3.5, 'wind_cdir_full': 'west-southwest', 'slp': 1008, 'datetime': '2024-06-16:00', 'ts': 1718496000, 'wind_gust_spd': 9.4, 'dewpt': 70.9, 'uv': 0, 'ozone': 275.3, 'clouds_hi': 100, 'clouds_low': 53, 'clouds_mid': 63, 'timestamp_utc': '2024-06-16T00:00:00', 'wind_dir': 237, 'timestamp_local': '2024-06-16T05:30:00', 'pop': 0, 'snow_depth': 0, 'precip': 0, 'weather': {'icon': 'c04n', 'description': 'Overcast clouds', 'code': 804}, 'dni': 0, 'app_temp': 75.3, 'temp': 74, 'clouds': 79, 'dhi': 0, 'ghi': 0}, {'wind_cdir': 'WSW', 'rh': 79, 'pod': 'd', 'pres': 947, 'snow': 0, 'vis': 14.9, 'solar_rad': 487.48724, 'wind_spd': 7.2, 'wind_cdir_full': 'west-southwest', 'slp': 1009.5, 'datetime': '2024-06-16:03', 'ts': 1718506800, 'wind_gust_spd': 16.3, 'dewpt': 71, 'uv': 3.4, 'ozone': 278.5, 'clouds_hi': 9, 'clouds_low': 58, 'clouds_mid': 16, 'timestamp_utc': '2024-06-16T03:00:00', 'wind_dir': 237, 'timestamp_local': '2024-06-16T08:30:00', 'pop': 0, 'snow_depth': 0, 'precip': 0, 'weather': {'icon': 'c02d', 'description': 'Scattered clouds', 'code': 802}, 'dni': 787.43, 'app_temp': 79.2, 'temp': 78, 'clouds': 0, 'dhi': 94.01, 'ghi': 519.46}, {'wind_cdir': 'WSW', 'rh': 59, 'pod': 'd', 'pres': 946.5, 'snow': 0, 'vis': 14.9, 'solar_rad': 945.0987, 'wind_spd': 8.1, 'wind_cdir_full': 'west-southwest', 'slp': 1008, 'datetime': '2024-06-16:06', 'ts': 1718517600, 'wind_gust_spd': 20, 'dewpt': 70.1, 'uv': 10.6, 'ozone': 272.3, 'clouds_hi': 9, 'clouds_low': 42, 'clouds_mid': 28, 'timestamp_utc': '2024-06-16T06:00:00', 'wind_dir': 258, 'timestamp_local': '2024-06-16T11:30:00', 'pop': 15, 'snow_depth': 0, 'precip': 0.001, 'weather': {'icon': 'c02d', 'description': 'Scattered clouds', 'code': 802}, 'dni': 928.86, 'app_temp': 90.9, 'temp': 86.1, 'clouds': 0, 'dhi': 121.87, 'ghi': 1004.69}, {'wind_cdir': 'WSW', 'rh': 59, 'pod': 'd', 'pres': 944.5, 'snow': 0, 'vis': 14.9, 'solar_rad': 681.6297, 'wind_spd': 8.8, 'wind_cdir_full': 'west-southwest', 'slp': 1006, 'datetime': '2024-06-16:09', 'ts': 1718528400, 'wind_gust_spd': 19.1, 'dewpt': 71.2, 'uv': 4.8, 'ozone': 273.8, 'clouds_hi': 5, 'clouds_low': 76, 'clouds_mid': 27, 'timestamp_utc': '2024-06-16T09:00:00', 'wind_dir': 251, 'timestamp_local': '2024-06-16T14:30:00', 'pop': 10, 'snow_depth': 0, 'precip': 0.005, 'weather': {'icon': 'c04d', 'description': 'Overcast clouds', 'code': 804}, 'dni': 904.85, 'app_temp': 93.1, 'temp': 87.2, 'clouds': 62, 'dhi': 116.57, 'ghi': 894.64}, {'wind_cdir': 'WSW', 'rh': 67, 'pod': 'd', 'pres': 944.5, 'snow': 0, 'vis': 12.4, 'solar_rad': 260.7525, 'wind_spd': 8.4, 'wind_cdir_full': 'west-southwest', 'slp': 1006, 'datetime': '2024-06-16:12', 'ts': 1718539200, 'wind_gust_spd': 17.9, 'dewpt': 71.1, 'uv': 2, 'ozone': 274.3, 'clouds_hi': 0, 'clouds_low': 52, 'clouds_mid': 6, 'timestamp_utc': '2024-06-16T12:00:00', 'wind_dir': 242, 'timestamp_local': '2024-06-16T17:30:00', 'pop': 20, 'snow_depth': 0, 'precip': 0.008, 'weather': {'icon': 'r04d', 'description': 'Light shower rain', 'code': 520}, 'dni': 646.41, 'app_temp': 88, 'temp': 83.2, 'clouds': 0, 'dhi': 72.44, 'ghi': 277.85}, {'wind_cdir': 'SW', 'rh': 79, 'pod': 'n', 'pres': 946.5, 'snow': 0, 'vis': 14.9, 'solar_rad': 0, 'wind_spd': 5.1, 'wind_cdir_full': 'southwest', 'slp': 1008.5, 'datetime': '2024-06-16:15', ' ...
# state_code 19
# lon 75.638
# lat 14.611
# city_name Rānībennur
# country_code IN
# timezone Asia/Kolkata
#
# ..............................................................................................
#
#
# ..............................................................................................
#
# hey Bharat
#
#     what you wish to do now
#     1. check wheather
#     2. go back to previous menu
#     3. Exit
# enter your choice2
#
#     hey Bharat choose what you wish to do
#     1.Register
#     2.Login
#     3.aise hei chala aya
# enter your choice3
#
# ..............................................................................................
#
# aise kaise
